# %% [markdown]
# # Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in predicting the quality of wine.

# %% [markdown]
# ## `The Wine Quality dataset is a popular dataset used in machine learning and data analysis tasks, particularly for regression and classification problems. It contains information about various chemical properties of wine and its associated quality ratings. The dataset is often used to predict the quality of wine based on these chemical features`

# %% [raw]
# There are many columns in this dataset:
#
# fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality']

# %% [raw]
# Fixed Acidity: Fixed acidity is the concentration of non-volatile acids in the wine, primarily tartaric acid. It plays a role in determining the overall taste and structure of the wine. A proper balance of acidity is crucial for wine quality, as it contributes to the wine's freshness and stability.
#
# Volatile Acidity: Volatile acidity represents the concentration of volatile acids, mainly acetic acid, in the wine. Too much volatile acidity can lead to unpleasant vinegar-like flavors and is generally considered a defect. Predicting and controlling this feature is vital for maintaining wine quality.
#
# Citric Acid: Citric acid is one of the non-volatile acids found in wine and is naturally present in grapes. It can enhance the wine's freshness and contribute to its overall balance.
#
# Residual Sugar: Residual sugar is the amount of sugar that remains in the wine after fermentation. It can significantly affect the wine's sweetness level and mouthfeel. Predicting residual sugar is essential for understanding a wine's style and whether it is dry, semi-sweet, or sweet.
#
# Chlorides: Chlorides in wine primarily come from salt. Excessive chloride levels can lead to a salty taste, which is undesirable in most wines. Predicting and controlling chloride levels is necessary for maintaining wine balance.
#
# Free Sulfur Dioxide: Free sulfur dioxide is used in winemaking as a preservative and antioxidant. It helps protect the wine from spoilage and oxidation. Proper levels of free sulfur dioxide are crucial for wine quality and shelf life.
#
# Total Sulfur Dioxide: Total sulfur dioxide includes both free and bound sulfur dioxide. High levels of total sulfur dioxide can have adverse effects on wine quality, including undesirable sulfurous odors. Predicting and controlling total sulfur dioxide is essential for wine stability.
#
# Density: The density of wine is related to its sugar content and alcohol level. It can affect the mouthfeel and body of the wine. Predicting density is important for understanding the wine's texture.
#
# pH: pH measures the acidity or alkalinity of the wine. It can influence the wine's overall balance and taste. Proper pH levels are critical for wine stability and quality.
#
# Sulphates: Sulphates, primarily in the form of potassium sulfate, are often added to wine to promote fermentation and stability. They can also contribute to the wine's aroma and flavor. Predicting sulphate levels is important for winemaking consistency.
#
# Alcohol: The alcohol content of wine is a critical component of its taste, mouthfeel, and overall style. The alcohol level significantly influences the wine's body and perceived sweetness.
#
# Quality (Target Variable): This is the target variable and represents the quality rating of the wine, typically on a scale from 3 to 8 (or 1 to 10 in some versions of the dataset). It is used to assess the overall quality of the wine, with higher values indicating better quality.
#
#
#
# --- each feature in the Wine Quality dataset represents a chemical property of wine that can influence its taste, aroma, stability, and overall quality

# %% [markdown]
# # Q2. How did you handle missing data in the wine quality data set during the feature engineering process? Discuss the advantages and disadvantages of different imputation techniques.

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv')

# %%
df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## `As far As I can See. There are no null and missing values present in this wine dataset.But But in feature or any wine dataset is found then missing or null value then:`

# %% [markdown]
# ## Mean/Median Imputation:
#
# `Advantages:`
#
# Simple and easy to implement.
#
# Does not introduce bias into the data.
#
# Works well when data is missing at random.
#
#
#
# `Disadvantages:`
#
# May not be appropriate when missing data is not missing at random (MAR)
#
#
# Reduces the variance but does not capture the underlying data distribution.
#
# Mode Imputation (for Categorical Data):

# %% [markdown]
# ## Regression Imputation:
#
# `Advantages:`
#
# Utilizes relationships between variables to make more informed imputations.
#
# Can handle both continuous and categorical variables.
#
# `Disadvantages:`
#
# Requires significant computational resources, especially for large datasets.
#
#
# Sensitive to the choice of regression model.
#
# Assumes a linear relationship between variables, which may not hold in all cases.
#
#
# # K-Nearest Neighbors (K-NN) Imputation:`
#
# `Advantages:`
#
# Considers the similarity between data points to impute missing values.
#
# Non-parametric approach that does not assume linearity.
#
# `Disadvantages:`
#
# Computationally intensive, especially for large datasets.
#
# Sensitive to the choice of the number of neighbors (k).

# %% [raw]
# -->> Dropping Rows/Columns:
#
# -- Advantages:
#
# Simple and avoids introducing bias or making assumptions about the data.
# May be acceptable when the proportion of missing data is small.
#
#
# --Disadvantages:
# Can result in a loss of information, especially if many rows or columns are removed.
# Reduces the effective sample size, which can affect the model's performance.

# %% [markdown]
# # Q3. What are the key factors that affect students' performance in exams? How would you go about analyzing these factors using statistical techniques?

# %% [markdown]
# ## Study Habits: Effective study habits, including time management, note-taking, and active learning techniques, can have a significant impact on exam performance.
#
#
# ## Teacher Quality: The quality of instruction and the teaching methods used by educators can impact how well students grasp and retain information.
#
#
# ## Motivation and Engagement: A motivated and engaged student is more likely to put in the effort required for successful exam performance.
#
#
#
# ## Resources: Access to textbooks, online resources, libraries, and study materials can affect students' ability to prepare for exams.
#
#
# ## Parental Support: Parental involvement and support in a student's education can positively influence performance.

# %% [markdown]
# `Analyzing these factors using statistical techniques involves the following steps:`
#
# ## Data Collection: Gather data on these factors from students, educators, and relevant sources. This data may include student demographics, academic records, survey responses, and educational resources.
#
#
# ## Data Preprocessing: Clean and prepare the data for analysis. Address missing data, encode categorical variables, and perform data transformations as necessary.
#
#
#
# ## Exploratory Data Analysis (EDA): Conduct EDA to understand the data's characteristics and relationships. Use descriptive statistics, visualizations, and correlation analysis to identify patterns and potential relationships between factors and exam performance.
#
#
#
# ## Machine Learning: Consider using machine learning techniques, such as classification or predictive modeling, to build predictive models of exam performance based on the identified factors.
#
#
# ## Interpretation and Reporting: Interpret the results of your analysis and report your findings. Highlight the key factors that have a substantial impact on exam performance and provide recommendations or insights for educational improvement.

# %% [markdown]
# # Q4. Describe the process of feature engineering in the context of the student performance data set. How did you select and transform the variables for your model?

# %% [markdown]
# ## `Feature engineering is a crucial step in the data preprocessing process, where we select, create, or transform features (variables) to improve the performance of your machine learning model. In the context of a student performance dataset, feature engineering can involve various steps to extract meaningful information from the available data`

# %% [raw]
# Data Collection and Understanding:
#
# Gather the student performance dataset, including information on student demographics, academic records, and any other relevant variables.
# Understand the dataset's structure, variable types, and relationships between variables.
#
#
#
# Handling Missing Data:
#
# Identify and handle missing values in the dataset using appropriate imputation techniques.
# Decide whether to drop or impute missing data based on the nature of the missingness.
#
#
# Feature Selection:
#
# Analyze the relevance and importance of each variable with respect to predicting student performance.
# Use techniques like correlation analysis, feature importance scores from machine learning models, or domain knowledge to select the most informative features.
#
#
# Creating New Features:
#
# Generate new features that might capture additional information or relationships in the data.
# For example, you can create a "study time" feature by combining variables related to daily study hours and weekly study hours.
#
#
# Encoding Categorical Variables:
#
# If your dataset contains categorical variables (e.g., gender, school type), encode them into numerical format using techniques like one-hot encoding or label encoding.
#
#
# Scaling or Normalizing Features:
#
# Standardize or normalize numerical features to bring them to a common scale, especially if you're using models sensitive to feature scales (e.g., SVM, k-NN).
#
#
# Feature Engineering Based on Domain Knowledge:
#
# Incorporate domain-specific knowledge to create features that are known to be relevant. For example, you might calculate a student's average grade in a specific subject over time if subject-specific performance is important.
#
#
# Dimensionality Reduction:
#
# Apply dimensionality reduction techniques like Principal Component Analysis (PCA) or t-SNE to reduce the dimensionality of the feature space while preserving important information.
#
# Feature Scaling:
#
# Ensure that all features are on a similar scale to avoid dominance by features with larger scales. This step is particularly important for models like k-NN or gradient-based algorithms.
#
# Feature Engineering Iteration:
#
# Iteratively explore, select, and engineer features based on the performance of your machine learning model. Continuously refine your feature set to improve model accuracy.
#
# Cross-Validation:
#
# Use cross-validation techniques to evaluate the performance of your model with different feature sets and configurations, helping you identify the best feature engineering choices.

# %% [markdown]
# # Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to these features to improve normality?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
df = pd.read_csv('winequality-red.csv')

# %%
#summary of the datset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#descriptive summary of the dataset

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#shape of the dataset
df.shape
# Out:
# (1599, 12)

# %%
#list down all the columns
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['alcohol'].unique()
# Out:
# array([ 9.4       ,  9.8       , 10.        ,  9.5       , 10.5       ,
#         9.2       ,  9.9       ,  9.1       ,  9.3       ,  9.        ,
#         9.7       , 10.1       , 10.6       ,  9.6       , 10.8       ,
#        10.3       , 13.1       , 10.2       , 10.9       , 10.7       ,
#        12.9       , 10.4       , 13.        , 14.        , 11.5       ,
#        11.4       , 12.4       , 11.        , 12.2       , 12.8       ,
#        12.6       , 12.5       , 11.7       , 11.3       , 12.3       ,
#        12.        , 11.9       , 11.8       ,  8.7       , 13.3       ,
#        11.2       , 11.6       , 11.1       , 13.4       , 12.1       ,
#         8.4       , 12.7       , 14.9       , 13.2       , 13.6       ,
#        13.5       , 10.03333333,  9.55      ,  8.5       , 11.06666667,
#         9.56666667, 10.55      ,  8.8       , 13.56666667, 11.95      ,
#         9.95      ,  9.23333333,  9.25      ,  9.05      , 10.75      ])

# %%
# checking missing value
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# To check duplicate value in this dataset

df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
import seaborn as sns
sns.histplot(df['fixed acidity'],kde= True)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Count'>

# %%
sns.histplot(df['pH'],kde =True)
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
#categorical plot
df = sns.catplot(x= 'quality',y= 'alcohol',data=df,kind= 'box')

# %%
# List of numerical features to analyze
numerical_features = ["alcohol", "volatile acidity", "citric acid", 
                      "residual sugar", "chlorides", "free sulfur dioxide",
                      "total sulfur dioxide",
                      "density", "pH", "sulphates"
                     ]


# Loop through each numerical feature
for feature in numerical_features:
    # Create subplots for histograms and Q-Q plots
    plt.figure(figsize=(12, 5))
    
  # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(df[feature], kde=True)
    plt.title(f'Histogram of {feature}')
    
    # Q-Q Plot
    plt.subplot(1, 2, 2)
    stats.probplot(df[feature], plot=plt)
    plt.title(f'Q-Q Plot of {feature}')
    
    # Perform the Shapiro-Wilk test for normality
    shapiro_test = stats.shapiro(df[feature])
    p_value = shapiro_test[1]
    
    # Print the result of the Shapiro-Wilk test
    if p_value < 0.05:
        print(f'{feature} is not normally distributed (p-value = {p_value:.4f})')
    else:
        print(f'{feature} is normally distributed (p-value = {p_value:.4f})')
    
    plt.show()
# Out:
# alcohol is not normally distributed (p-value = 0.0000)
# volatile acidity is not normally distributed (p-value = 0.0000)
# citric acid is not normally distributed (p-value = 0.0000)
# residual sugar is not normally distributed (p-value = 0.0000)
# chlorides is not normally distributed (p-value = 0.0000)
# free sulfur dioxide is not normally distributed (p-value = 0.0000)
# total sulfur dioxide is not normally distributed (p-value = 0.0000)
# density is not normally distributed (p-value = 0.0000)
# pH is not normally distributed (p-value = 0.0000)
# sulphates is not normally distributed (p-value = 0.0000)

# %%
shapiro_test,p_value
# Out:
# (ShapiroResult(statistic=0.8330425024032593, pvalue=5.821617678881608e-38),
#  5.821617678881608e-38)

# %% [markdown]
# # Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number offeatures. What is the minimum number of principal components required to explain 90% of the variance inthe data?

# %% [markdown]
# ## Principal Component Analysis (PCA) is a dimensionality reduction technique used to reduce the number of features while retaining most of the variance in the data. To determine the minimum number of principal components required to explain 90% of the variance in the Wine Quality dataset,

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load the Wine Quality dataset 
df = pd.read_csv('winequality-red.csv')

# %%
df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %%
# Separate the features (X) and the target variable (y)
X = df.drop("quality", axis=1)
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Standardize the features (important for PCA)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
scaler
# Out:
# StandardScaler()

# %%
X_scaled
# Out:
# array([[-0.52835961,  0.96187667, -1.39147228, ...,  1.28864292,
#         -0.57920652, -0.96024611],
#        [-0.29854743,  1.96744245, -1.39147228, ..., -0.7199333 ,
#          0.1289504 , -0.58477711],
#        [-0.29854743,  1.29706527, -1.18607043, ..., -0.33117661,
#         -0.04808883, -0.58477711],
#        ...,
#        [-1.1603431 , -0.09955388, -0.72391627, ...,  0.70550789,
#          0.54204194,  0.54162988],
#        [-1.39015528,  0.65462046, -0.77526673, ...,  1.6773996 ,
#          0.30598963, -0.20930812],
#        [-1.33270223, -1.21684919,  1.02199944, ...,  0.51112954,
#          0.01092425,  0.54162988]])

# %%
# Initialize PCA with n_components=None to keep all components initially
pca = PCA(n_components=None) 
# n_components=None, which means that initially, it will keep all principal components.
# Fit PCA on the scaled data
pca.fit(X_scaled)
pca
# Out:
# PCA()

# %%
# Calculate the explained variance ratio for each component
explained_variance_ratio = pca.explained_variance_ratio_

# Calculate cumulative explained variance
cumulative_explained_variance = explained_variance_ratio.cumsum()

# Find the minimum number of components to explain 90% of the variance
n_components_to_explain_90_percent = (
    cumulative_explained_variance >= 0.90
).sum() + 1  # Add 1 because indexing starts from 0



print(
    f"Minimum number of components to explain 90% of variance: {n_components_to_explain_90_percent}"
)
# Out:
# Minimum number of components to explain 90% of variance: 6

# %% [markdown]
# # `we determine the minimum number of components required to explain 90% of the variance by finding the index where the cumulative explained variance first exceeds or equals 90%.`
